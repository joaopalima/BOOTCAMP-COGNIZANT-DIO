# %%
import pandas as pd

# %%
df = pd.read_csv('ocorrencia.csv', sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head() #imprime as primeiras 5 linhas
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.loc[1,'ocorrencia_cidade'] #dado de uma interseção
#df.loc[:,'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %% [raw]
# df.loc[3] ## traz os dados da linha3
# #df.loc[1:3] ## traz os dados da linha 1 até 3
# #df.loc[[10,40]] ## traz os dados da linha 10 e 40
# #df.loc[:,'ocorrencia_cidade'] ##traz todos dados de uma coluna e não informa a linha

# %%
df.codigo_ocorrencia.is_unique #verifica se é unica(valor se repete apenas uma vez?)
##df.ocorrencia_uf.is_unique # não é unica
# Out:
# True

# %%
## alterar índice do dataframe que não tenho repsitção de valor
##df.set_index('codigo_ocorrencia') ## não fez alteração, só fez validação
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head() #imprime os 5 primeiros "codigdo da ocorrencia" como ìndece
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df.loc[45407] ## vai imprimir todos dados da linha escolhida - índice
# Out:
# codigo_ocorrencia2                        45407
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                      SÃO SEPÉ
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        16:30:00
# total_recomendacoes                           0
# Name: 45407, dtype: object

# %%
#eclui index atual
df.reset_index(drop=True, inplace=True) ##reseta o ìndex original

# %%
df.head() #imprime o index original
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0             52242.0                INCIDENTE      PORTO ALEGRE
# 1             45331.0                 ACIDENTE         GUARULHOS
# 2             45333.0                 ACIDENTE            VIAMÃO
# 3             45401.0                 ACIDENTE     SÃO SEBASTIÃO
# 4             45407.0                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                 ****     2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                  0.0
# 1                  3.0
# 2                  0.0
# 3                  0.0
# 4                  0.0

# %% [raw]
# aletração dos dados do aerodromo com "****"

# %%
df.loc[2,'ocorrencia_aerodromo'] = '' #aletração dos dados do aerodromo com "****" na linha 2

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0             52242.0                INCIDENTE      PORTO ALEGRE
# 1             45331.0                 ACIDENTE         GUARULHOS
# 2             45333.0                 ACIDENTE            VIAMÃO
# 3             45401.0                 ACIDENTE     SÃO SEBASTIÃO
# 4             45407.0                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                  0.0
# 1                  3.0
# 2                  0.0
# 3                  0.0
# 4                  0.0

# %% [raw]
# alterar todos dados de uma linha

# %%
df.loc[1] = 20 # altera dados para 20 em todas as colunas da linha 1

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0             52242.0                INCIDENTE      PORTO ALEGRE
# 1                20.0                       20                20
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA  2012-01-05 00:00:00        20:27:00
# 1            20                   20                   20              20
#
#    total_recomendacoes
# 0                  0.0
# 1                 20.0

# %% [raw]
# alterar todos dados de uma coluna

# %%
df.loc[:,'total_recomendacoes'] = 10 # coluna 'total_recomendacoes' vai receveber valor de 10 em todas as linhas

# %%
df #imprime toda a tabela
#df.head() imprime as 5 primeiras linhas
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                52242.0                INCIDENTE      PORTO ALEGRE
# 1                   20.0                       20                20
# 2                45333.0                 ACIDENTE            VIAMÃO
# 3                45401.0                 ACIDENTE     SÃO SEBASTIÃO
# 4                45407.0                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5163             80452.0                 ACIDENTE           MARACAÍ
# 5164             80457.0          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165             80460.0                INCIDENTE          CURITIBA
# 5166             80467.0                INCIDENTE         PETROLINA
# 5167                 NaN                      NaN               NaN
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [raw]
# criando backup para não perder os dados originais

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf # cria a coluna "ocorrencia_uf_bkp"

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                52242.0                INCIDENTE      PORTO ALEGRE
# 1                   20.0                       20                20
# 2                45333.0                 ACIDENTE            VIAMÃO
# 3                45401.0                 ACIDENTE     SÃO SEBASTIÃO
# 4                45407.0                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5163             80452.0                 ACIDENTE           MARACAÍ
# 5164             80457.0          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165             80460.0                INCIDENTE          CURITIBA
# 5166             80467.0                INCIDENTE         PETROLINA
# 5167                 NaN                      NaN               NaN
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [raw]
# alterar a "ocorrencia_classificacao" para grave onde a "ocorrencia_uf" = "SP"

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df #imprime as alterações em SP para grave
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# limpeza no dataframe local / executa a planilha original na linha 2 e faz leitura no final.

# %%
df # imprime a planilha original após executar na linha 2
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ****
# *****
# ####
# ###!
# ocorrencia_hora
# NULL

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] == pd.NA
# Out:
# Empty DataFrame
# Columns: [ocorrencia_aerodromo]
# Index: []

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.replace(['**','*****','****','####','###!','NULL'], pd.NA, inplace=True) # altera os dados não avaliados no dataframe

# %% [raw]
# df.isna().sum() # imprime a soma dos dados não informados em casa coluna
# df.isnull()
# df.isnull().sum() # imprime a soma dos dados não informados em casa coluna

# %%
#df.tail()
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [raw]
# bota valor em dado não informado, por o valor 0

# %%
df.fillna(0) # em todos dados não informados foi adicionado o valor 0
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.fillna(10, inplace=True) # tudo que era NA agora passou para 10

# %%
df.isnull().sum() # imprime a soma dos daos não informados >>> NA foi alterado para 10
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                   10     2012-01-06
# 3     SÃO SEBASTIÃO            SP                   10     2012-01-06
# 4          SÃO SEPÉ            RS                   10     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.replace([10], pd.NA, inplace=True) #altera de '10' para NA novamente

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 <NA>     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4          SÃO SEPÉ            RS                 <NA>     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %% [raw]
# eclusão da dados no data frame

# %%
#excluir coluna que criou no DF
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ecluir coluna de backup >>> alterar axis para 1(coluna, por padrão é 0(linha)
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ecluiu todas as linhas com dados NA
df.dropna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 6                 50713               50713          INCIDENTE GRAVE
# 7                 45334               45334                INCIDENTE
# 9                 52244               52244                INCIDENTE
# ...                 ...                 ...                      ...
# 5160              80451               80451                INCIDENTE
# 5161              80456               80456                INCIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dropna(subset=['ocorrencia_uf']) #ecluiu as linhas com os valores não informados na coluna 'ocorrencia_uf'
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5162              80458               80458                 ACIDENTE
# 5163              80452               80452                 ACIDENTE
# 5164              80457               80457          INCIDENTE GRAVE
# 5165              80460               80460                INCIDENTE
# 5166              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#retira valores duplicados
df.drop_duplicate()
#df.drop_duplicate(inplace=True) #faz alreação dentro do 'df'
